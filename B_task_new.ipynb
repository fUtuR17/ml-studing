# %% [markdown]
# <a href="https://colab.research.google.com/github/fUtuR17/ml-studing/blob/1.3/B_task_new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msn
# %matplotlib inline

from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("organisations.csv")
features = pd.read_csv("features.csv")
rubrics = pd.read_csv("rubrics.csv")

# %%
rubric_names = rubrics.set_index("rubric_id")["rubric_name"].to_dict()
print(rubric_names)

feature_names = features.set_index("feature_id")["feature_name"].to_dict()
print(feature_names)
# Out:
# {30519: 'Булочная, пекарня', 30770: 'Бар, паб', 30771: 'Быстрое питание', 30774: 'Кафе', 30775: 'Пиццерия', 30776: 'Ресторан', 30777: 'Столовая', 31286: 'Спортбар', 31350: 'Кондитерская', 31375: 'Суши-бар', 31401: 'Кальян-бар', 31495: 'Кофейня', 3108292683: 'Бар безалкогольных напитков', 3501514558: 'Фудкорт', 3501750896: 'Кофе с собой'}
# ...

# %%
data = data.dropna(subset=["average_bill"])
data = data[data['average_bill'] <= 2500]
msn.matrix(data)
# Out:
# <Axes: >

# %%
means = data.groupby("city")["average_bill"].mean()
msk_mean = means.get("msk", 0)
spb_mean = means.get("spb", 0)

print(round(msk_mean - spb_mean))
# Out:
# 116
